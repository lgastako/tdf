-- %%
:set -v
-- Out:
-- *** Parser [source]:
-- !!! Parser [source]: finished in 0.07 milliseconds, allocated 0.085 megabytes
-- *** Desugar:
-- *** Simplify [expr]:
-- !!! Simplify [expr]: finished in 0.11 milliseconds, allocated 0.124 megabytes
-- *** CorePrep [expr]:
-- !!! CorePrep [expr]: finished in 0.09 milliseconds, allocated 0.043 megabytes
-- *** ByteCodeGen [Ghci8]:
-- !!! ByteCodeGen [Ghci8]: finished in 0.73 milliseconds, allocated 0.134 megabytes
-- *** Parser [source]:
-- !!! Parser [source]: finished in 0.05 milliseconds, allocated 0.085 megabytes
-- *** Desugar:
-- *** Simplify [expr]:
-- !!! Simplify [expr]: finished in 0.09 milliseconds, allocated 0.124 megabytes
-- *** CorePrep [expr]:
-- !!! CorePrep [expr]: finished in 0.04 milliseconds, allocated 0.043 megabytes
-- *** ByteCodeGen [Ghci9]:
-- !!! ByteCodeGen [Ghci9]: finished in 0.08 milliseconds, allocated 0.134 megabytes
-- *** Parser [source]:
-- !!! Parser [source]: finished in 0.05 milliseconds, allocated 0.049 megabytes
-- ...

-- %%
import qualified TDF.DataFrame as DF
-- Out:
-- <interactive>:1:1: error:
--     Could not find module ‘TDF.DataFrame’
--     Locations searched:
--       TDF/DataFrame.hs
--       TDF/DataFrame.lhs
--       TDF/DataFrame.hsig
--       TDF/DataFrame.lhsig

-- %%
import Data.Row.Records
-- Out:
-- *** Parser [source]:
-- !!! Parser [source]: finished in 0.07 milliseconds, allocated 0.070 megabytes
-- *** Desugar:
-- *** Simplify [expr]:
-- !!! Simplify [expr]: finished in 0.56 milliseconds, allocated 0.124 megabytes
-- *** CorePrep [expr]:
-- !!! CorePrep [expr]: finished in 0.07 milliseconds, allocated 0.044 megabytes
-- *** ByteCodeGen [Ghci25]:
-- !!! ByteCodeGen [Ghci25]: finished in 0.12 milliseconds, allocated 0.134 megabytes
-- *** Parser [source]:
-- !!! Parser [source]: finished in 0.07 milliseconds, allocated 0.070 megabytes
-- *** Desugar:
-- *** Simplify [expr]:
-- !!! Simplify [expr]: finished in 0.24 milliseconds, allocated 0.124 megabytes
-- *** CorePrep [expr]:
-- !!! CorePrep [expr]: finished in 0.05 milliseconds, allocated 0.044 megabytes
-- *** ByteCodeGen [Ghci26]:
-- !!! ByteCodeGen [Ghci26]: finished in 0.10 milliseconds, allocated 0.134 megabytes
-- *** Parser [source]:
-- !!! Parser [source]: finished in 0.09 milliseconds, allocated 0.049 megabytes
-- ...
